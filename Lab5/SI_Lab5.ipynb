# %%
# Import bibliotek
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional, Input
from keras.optimizers import SGD, Adam
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from keras.losses import Huber

# %%
# Funkcje pomocnicze: wykres predykcji modelu, metryki oceny modelu RMSE i MAE)
# Jeśli RMSE jest dużo wyższe niż MAE, oznacza to, że model radzi sobie dobrze przez większość czasu,
# ale "wywala się" na kilku konkretnych dniach (np. przy nagłych krachach giełdowych).
def plot_predictions(test, predicted):
    plt.plot(test, color='red', label='Real IBM Stock Price')
    plt.plot(predicted, color='blue', label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()

def return_rmse(test, predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("-" * 30)
    print("Błąd średniokwadratowy modelu {:.2f}.".format(rmse))
    print("-" * 30)

def return_mae(test, predicted):
    mae = mean_absolute_error(test, predicted)
    mape = mean_absolute_percentage_error(test, predicted) * 100
    print("Średni błąd bezwzględny: {:.2f}.".format(mae))
    print("Średni błąd bezwzględny procentowy: {:.2f}%".format(mape))
    print("-" * 30)

# %%
# Wczytanie danych
dataset = pd.read_csv('IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# Ustawiamy zbiory trenujące i testowe oraz szukamy brakujących wartości
training_set = dataset[:'2016'].iloc[:, 1:2].values
test_set = dataset['2017':].iloc[:, 1:2].values

#training_set = dataset[:'2016'].iloc[:, 3:4].values
#test_set = dataset['2017':].iloc[:, 3:4].values

#dataset["Close"][:'2016'].plot(figsize=(16,4), legend=True)
#dataset["Close"]['2017':].plot(figsize=(16,4), legend=True)

# %%
# Wizualizacja danych
dataset["High"][:'2016'].plot(figsize=(16, 4), legend=True)
dataset["High"]['2017':].plot(figsize=(16, 4), legend=True)
plt.legend(['Training set (Before 2017)', 'Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
# Normalizacja danych trenujących
sc = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Ponieważ komórki LSTM przechowują stan pamięci długotrwałej,
# tworzymy strukturę danych z 60 krokami czasowymi i 1 wyjściem
# Zatem dla każdego elementu zestawu treningowego mamy 60 poprzednich elementów zestawu treningowego.
X_train = []
y_train = []
for i in range(60, 2769):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Przekształcanie X_train w celu zapewnienia wydajnego modelowania
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Blok 9
# Architektura LSTM, sieć regresyjna, predykująca
regressor = Sequential()
# Warstwa wejściowa
regressor.add(Input(shape=(X_train.shape[1], 1)))
# Pierwsza warstwa LSTM
regressor.add(LSTM(units=100, return_sequences=True))
regressor.add(Dropout(0.2))
# Druga warstwa LSTM z regularyzacją Dropout
regressor.add(LSTM(units=100, return_sequences=True))
regressor.add(Dropout(0.2))
# Trzecia warstwa LSTM z regularyzacją Dropout
regressor.add(LSTM(units=100, return_sequences=True))
regressor.add(Dropout(0.2))
# Czwarta warstwa LSTM z regularyzacją Dropout
regressor.add(LSTM(units=100))
regressor.add(Dropout(0.2))
# Warstwa wyjściowa
regressor.add(Dense(units=1))

# Ustawimy funkcję optymalizującą wagi (uczącą) i funkcję straty
regressor.compile(optimizer='rmsprop', loss='mean_squared_error')

# MAE
#regressor.compile(optimizer='rmsprop', loss='mean_absolute_error')

#Huber
#regressor.compile(optimizer='rmsprop', loss='Huber')

#Test adam
#regressor.compile(optimizer='adam', loss='mean_squared_error')

#Test SGD
#opt_sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#regressor.compile(optimizer=opt_sgd, loss='mean_squared_error')

# Trenujemy sieć, ustawiamy ilość epok i ilość podawanych próbek ze zbioru trenującego
#regressor.fit(X_train, y_train, epochs=50, batch_size=32)

# Wersja treningu z mechanizmem Early Stopping zapobiegającym przeuczeniu się sieci
# (zakomentować powyższe, odkomentować poniższe)
early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
regressor.fit(X_train, y_train, epochs=100, batch_size=32, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0351
# Epoch 2/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0120
# Epoch 3/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0084
# Epoch 4/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0070
# Epoch 5/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0059
# Epoch 6/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0051
# Epoch 7/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0042
# Epoch 8/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0040
# Epoch 9/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0039
# Epoch 10/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0033
# Epoch 11/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0032
# Epoch 12/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0029
# Epoch 13/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030
# Epoch 14/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0025
# Epoch 15/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0026
# Epoch 16/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0026
# Epoch 17/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0025
# Epoch 18/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0024
# Epoch 19/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021
# Epoch 20/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0022
# Epoch 21/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021
# Epoch 22/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0020
# Epoch 23/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018
# Epoch 24/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021
# Epoch 25/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018
# Epoch 26/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0019
# Epoch 27/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0019
# Epoch 28/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018
# Epoch 29/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019
# Epoch 30/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018
# Epoch 31/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017
# Epoch 32/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017
# Epoch 33/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017
# Epoch 34/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016
# Epoch 35/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0017
# Epoch 36/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0016
# Epoch 37/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016
# Epoch 38/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015
# Epoch 39/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014
# Epoch 40/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015
# Epoch 41/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016
# Epoch 42/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014
# Epoch 43/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015
# Epoch 44/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015
# Epoch 45/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0015
# Epoch 46/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0014
# Epoch 47/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0014
# Epoch 48/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014
# Epoch 49/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014
# Epoch 50/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013
# Epoch 51/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014
# Epoch 52/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013
# Epoch 53/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013
# Epoch 54/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0013
# Epoch 55/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012
# Epoch 56/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012
# Epoch 57/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012
# Epoch 58/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013
# Epoch 59/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012
# Epoch 60/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012
# Epoch 61/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013
# Epoch 62/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012
# Epoch 63/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0013
# Epoch 64/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0011
# Epoch 65/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011
# Epoch 66/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012
# Epoch 67/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011
# Epoch 68/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011
# Epoch 69/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012

# %%
# Podpinkt E.
# --- OSTATECZNA KONFIGURACJA DLA LSTM (PRZEBICIE BARIERY RMSE < 2.0) ---
from keras.optimizers import Adam

regressor = Sequential()

# Warstwa wejściowa
regressor.add(Input(shape=(X_train.shape[1], 1)))

# 4 Warstwy LSTM o zrównoważonej strukturze jednostek
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.1)) # Zmniejszamy delikatnie dropout, aby sieć nie gubiła dynamiki zmian

regressor.add(LSTM(units=32, return_sequences=True))
regressor.add(Dropout(0.1))

regressor.add(LSTM(units=32))
regressor.add(Dropout(0.1))

# Warstwa wyjściowa
regressor.add(Dense(units=1))

# Strata Hubera doskonale radzi sobie z nagłymi skokami cen (jak ten przy Time=200)
regressor.compile(optimizer=Adam(learning_rate=0.005), loss='Huber')

# Early stopping monitorujący stratę na zbiorze walidacyjnym
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Trenujemy na maksymalnie 100 epok z wydzieleniem 10% danych na walidację
regressor.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - loss: 0.0127 - val_loss: 0.0014
# Epoch 2/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0020 - val_loss: 6.3067e-04
# Epoch 3/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - val_loss: 5.7072e-04
# Epoch 4/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 4.8639e-04
# Epoch 5/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 5.8395e-04
# Epoch 6/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 7.3776e-04
# Epoch 7/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0014 - val_loss: 6.3250e-04
# Epoch 8/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0011 - val_loss: 3.4024e-04
# Epoch 9/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 7.3032e-04
# Epoch 10/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - val_loss: 3.5489e-04
# Epoch 11/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.6179e-04 - val_loss: 3.0236e-04
# Epoch 12/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.4852e-04 - val_loss: 6.0648e-04
# Epoch 13/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.8966e-04 - val_loss: 3.7265e-04
# Epoch 14/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 9.1259e-04 - val_loss: 2.7522e-04
# Epoch 15/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 8.4494e-04 - val_loss: 2.6734e-04
# Epoch 16/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 7.8934e-04 - val_loss: 2.4795e-04
# Epoch 17/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.4271e-04 - val_loss: 2.6502e-04
# Epoch 18/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.9021e-04 - val_loss: 2.2914e-04
# Epoch 19/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.0734e-04 - val_loss: 3.8042e-04
# Epoch 20/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.8294e-04 - val_loss: 2.9006e-04
# Epoch 21/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.1985e-04 - val_loss: 6.9795e-04
# Epoch 22/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.4484e-04 - val_loss: 3.8828e-04
# Epoch 23/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.3148e-04 - val_loss: 3.8465e-04
# Epoch 24/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.3264e-04 - val_loss: 1.8816e-04
# Epoch 25/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.6916e-04 - val_loss: 3.3062e-04
# Epoch 26/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.7171e-04 - val_loss: 1.8328e-04
# Epoch 27/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 5.6600e-04 - val_loss: 1.6019e-04
# Epoch 28/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2671e-04 - val_loss: 3.5246e-04
# Epoch 29/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2910e-04 - val_loss: 2.5959e-04
# Epoch 30/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.4974e-04 - val_loss: 4.4584e-04
# Epoch 31/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.8469e-04 - val_loss: 2.4432e-04
# Epoch 32/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.3701e-04 - val_loss: 1.3496e-04
# Epoch 33/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5841e-04 - val_loss: 1.8204e-04
# Epoch 34/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5064e-04 - val_loss: 1.9975e-04
# Epoch 35/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.8010e-04 - val_loss: 1.1965e-04
# Epoch 36/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4602e-04 - val_loss: 2.3998e-04
# Epoch 37/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6938e-04 - val_loss: 2.1528e-04
# Epoch 38/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.7908e-04 - val_loss: 1.2837e-04
# Epoch 39/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5028e-04 - val_loss: 1.1141e-04
# Epoch 40/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 4.5598e-04 - val_loss: 1.2224e-04
# Epoch 41/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 4.3387e-04 - val_loss: 1.0327e-04
# Epoch 42/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.7623e-04 - val_loss: 1.0004e-04
# Epoch 43/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4315e-04 - val_loss: 1.0528e-04
# Epoch 44/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5713e-04 - val_loss: 3.6863e-04
# Epoch 45/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8764e-04 - val_loss: 1.1403e-04
# Epoch 46/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9052e-04 - val_loss: 1.1338e-04
# Epoch 47/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9071e-04 - val_loss: 1.0601e-04
# Epoch 48/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.4942e-04 - val_loss: 1.0700e-04
# Epoch 49/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 4.6067e-04 - val_loss: 1.0099e-04
# Epoch 50/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 4.9142e-04 - val_loss: 1.3740e-04
# Epoch 51/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0019e-04 - val_loss: 9.6725e-05
# Epoch 52/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7400e-04 - val_loss: 9.0991e-05
# Epoch 53/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9184e-04 - val_loss: 1.1598e-04
# Epoch 54/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 4.9288e-04 - val_loss: 1.3341e-04
# Epoch 55/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 4.3291e-04 - val_loss: 3.1002e-04
# Epoch 56/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 3.6833e-04 - val_loss: 2.5237e-04
# Epoch 57/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5670e-04 - val_loss: 1.9685e-04
# Epoch 58/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1472e-04 - val_loss: 9.9409e-05
# Epoch 59/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2799e-04 - val_loss: 8.4219e-05
# Epoch 60/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8472e-04 - val_loss: 1.6634e-04
# Epoch 61/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7143e-04 - val_loss: 8.4042e-05
# Epoch 62/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2267e-04 - val_loss: 9.0235e-05
# Epoch 63/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6603e-04 - val_loss: 4.9547e-04
# Epoch 64/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 4.6741e-04 - val_loss: 1.4305e-04
# Epoch 65/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8888e-04 - val_loss: 2.5530e-04
# Epoch 66/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1197e-04 - val_loss: 2.8160e-04
# Epoch 67/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6842e-04 - val_loss: 1.3073e-04
# Epoch 68/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8023e-04 - val_loss: 9.1871e-05
# Epoch 69/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5845e-04 - val_loss: 1.0861e-04
# Epoch 70/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7421e-04 - val_loss: 1.0101e-04
# Epoch 71/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6969e-04 - val_loss: 1.1948e-04

# %%
# Teraz przygotujemy zestaw testowy w podobny sposób, jak zestaw treningowy.
# Poniższe czynności zostały wykonane tak,
# aby pierwsze 60 elementów zestawu testowego miało 60 poprzednich wartości
dataset_total = pd.concat((dataset["High"][:'2016'], dataset["High"]['2017':]), axis=0)

#dataset_total = pd.concat((dataset["Close"][:'2016'], dataset["Close"]['2017':]), axis=0)

inputs = dataset_total[len(dataset_total) - len(test_set) - 60:].values
inputs = inputs.reshape(-1, 1)
inputs = sc.transform(inputs)

# %%
# Przygotowanie X_testu i predykcja cen akcji
X_test = []
for i in range(60, 311):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step

# %%
# Wizualizacja wyników dla sieci LSTM
plot_predictions(test_set, predicted_stock_price)

# %%
# Ocena modelu
return_rmse(test_set, predicted_stock_price)
return_mae(test_set, predicted_stock_price)
# Out:
# ------------------------------
# Błąd średniokwadratowy modelu 1.69.
# ------------------------------
# Średni błąd bezwzględny: 1.06.
# Średni błąd bezwzględny procentowy: 0.66%
# ------------------------------

# %%
# blok 14
# Architektura GRU
regressorGRU = Sequential()
# Pierwsza warstwa GRU z regularyzacją Dropout
regressorGRU.add(Input(shape=(X_train.shape[1], 1)))
regressorGRU.add(GRU(units=50, return_sequences=True))
regressorGRU.add(Dropout(0.2))
# Druga warstwa GRU
regressorGRU.add(GRU(units=50, return_sequences=True))
regressorGRU.add(Dropout(0.2))
# Trzecia warstwa GRU
regressorGRU.add(GRU(units=50, return_sequences=True))
regressorGRU.add(Dropout(0.2))
# Czwarta warstwa GRU
regressorGRU.add(GRU(units=50))
regressorGRU.add(Dropout(0.2))
# Warstwa wyjściowa
regressorGRU.add(Dense(units=1))

# Kompilacja modelu
regressorGRU.compile(optimizer=SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True), loss='mean_squared_error')
# Dopasowanie do zestawu treningowego
regressorGRU.fit(X_train, y_train, epochs=50, batch_size=150)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0855
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0285
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0075
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0049
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0046
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0043
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0036
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0034
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0035
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0032
# Epoch 12/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0034
# Epoch 13/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031
# Epoch 14/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032
# Epoch 15/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0030
# Epoch 16/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028
# Epoch 17/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028
# Epoch 18/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0028
# Epoch 19/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0028
# Epoch 20/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027
# Epoch 21/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0024
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0025
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0022
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0022
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0022
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0021
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0022
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0022
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0022
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0021
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0020
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020

# %%
# Preparing X_test and predicting the prices
X_test = []
for i in range(60, 311):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
GRU_predicted_stock_price = regressorGRU.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
# Wizualizacja wyników dla sieci GRU
plot_predictions(test_set, GRU_predicted_stock_price)

# %%
# Ocena modelu
return_rmse(test_set, GRU_predicted_stock_price)
return_mae(test_set, GRU_predicted_stock_price)
# Out:
# ------------------------------
# Błąd średniokwadratowy modelu 3.23.
# ------------------------------
# Średni błąd bezwzględny: 2.20.
# Średni błąd bezwzględny procentowy: 1.39%
# ------------------------------
